# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("netflix_titles.csv")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.describe(include="all")
# Out:
#        show_id   type   title       director                cast  \
# count     8807   8807    8807           6173                7982
# unique    8807      2    8807           4528                7692
# top      s8807  Movie  Zubaan  Rajiv Chilaka  David Attenborough
# freq         1   6131       1             19                  19
# mean       NaN    NaN     NaN            NaN                 NaN
# std        NaN    NaN     NaN            NaN                 NaN
# min        NaN    NaN     NaN            NaN                 NaN
# 25%        NaN    NaN     NaN            NaN                 NaN
# 50%        NaN    NaN     NaN            NaN                 NaN
# 75%        NaN    NaN     NaN            NaN                 NaN
# max        NaN    NaN     NaN            NaN                 NaN
#
#               country       date_added  release_year rating  duration  \
# count            7976             8797   8807.000000   8803      8804
# ...

# %%
df['date_added'] = pd.to_datetime(df['date_added'].str.strip(), format="%B %d, %Y")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['date_added'] = pd.to_datetime(df['date_added'], format="mixed") #automatically knows the pattern of dates and convert it in.

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 825.8+ KB

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
#top 10 most common genres
genres= df['listed_in'].dropna().str.split(",")

# %%
genres
# Out:
# 0                                         [Documentaries]
# 1       [International TV Shows,  TV Dramas,  TV Myste...
# 2       [Crime TV Shows,  International TV Shows,  TV ...
# 3                               [Docuseries,  Reality TV]
# 4       [International TV Shows,  Romantic TV Shows,  ...
#                               ...
# 8802                   [Cult Movies,  Dramas,  Thrillers]
# 8803           [Kids' TV,  Korean TV Shows,  TV Comedies]
# 8804                           [Comedies,  Horror Movies]
# 8805                [Children & Family Movies,  Comedies]
# 8806    [Dramas,  International Movies,  Music & Music...
# Name: listed_in, Length: 8807, dtype: object

# %%
flat_genres=[]
for sublist in genres:
    for genre in sublist:
        flat_genres.append(genre)

# %%
from collections import Counter

# %%
genre_count= Counter(flat_genres)
top_10_genres=genre_count.most_common(10)

# %%
genre_df=pd.DataFrame(top_10_genres,columns=['Genre','Count'])
genre_df
# Out:
#                     Genre  Count
# 0    International Movies   2624
# 1                  Dramas   1600
# 2                Comedies   1210
# 3      Action & Adventure    859
# 4           Documentaries    829
# 5                  Dramas    827
# 6  International TV Shows    774
# 7      Independent Movies    736
# 8               TV Dramas    696
# 9         Romantic Movies    613

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
genres_split=df['listed_in'].dropna().str.split(',')

# %%
genres_split
# Out:
# 0                                         [Documentaries]
# 1       [International TV Shows,  TV Dramas,  TV Myste...
# 2       [Crime TV Shows,  International TV Shows,  TV ...
# 3                               [Docuseries,  Reality TV]
# 4       [International TV Shows,  Romantic TV Shows,  ...
#                               ...
# 8802                   [Cult Movies,  Dramas,  Thrillers]
# 8803           [Kids' TV,  Korean TV Shows,  TV Comedies]
# 8804                           [Comedies,  Horror Movies]
# 8805                [Children & Family Movies,  Comedies]
# 8806    [Dramas,  International Movies,  Music & Music...
# Name: listed_in, Length: 8807, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
genres_df.plot(kind="bar",color="m",linestyle="--",edgecolor='teal',linewidth=5,width=.5,alpha=0.5)
plt.xlabel("Genre")
plt.title("Top 10 most common Genres on Netflix")
plt.ylabel(" No of Titles")
plt.xticks(rotation=45)
plt.tight_layout()
plt.legend()
plt.show()

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
tv_shows=df[df['type']=='TV Show']
tv_shows['country'].value_counts().head(10)
# Out:
# country
# United States     760
# United Kingdom    213
# Japan             169
# South Korea       158
# India              79
# Taiwan             68
# Canada             59
# France             49
# Australia          48
# Spain              48
# Name: count, dtype: int64

# %%
tv_shows=df[df['type']=='TV Show']
tv_shows['country'].value_counts().head(10).plot(kind='bar',color="orange")
plt.title("Top 10 Countries by Number of Tv shows")
plt.xlabel("Country")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
df.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
movies_release=df[df['type']=='Movie']
movies_release['release_year'].value_counts()
# Out:
# release_year
# 2017    767
# 2018    767
# 2016    658
# 2019    633
# 2020    517
#        ...
# 1959      1
# 1963      1
# 1966      1
# 1946      1
# 1947      1
# Name: count, Length: 73, dtype: int64

# %%
movies_release=df[df['type']=='Movie']
movies_release['release_year'].value_counts().plot(kind="line",color="g",marker="o")
plt.title("Top Release year of Movies")
plt.xlabel("Release Year")
plt.ylabel("No of Movies")
plt.xticks(rotation=45)
plt.show()

# %%
# top directors with most content
df['director'].dropna().value_counts().head(5).plot(kind='bar',color='purple')
plt.title("Top 5 Directors by content Volume")
plt.xlabel("Directors")
plt.ylabel("No of Titles")
plt.xticks(rotation=45)
plt.show()

# %%
vs_plot=df.groupby(['release_year','type']).size().unstack()
vs_plot
# Out:
# type          Movie  TV Show
# release_year
# 1925            NaN      1.0
# 1942            2.0      NaN
# 1943            3.0      NaN
# 1944            3.0      NaN
# 1945            3.0      1.0
# ...             ...      ...
# 2017          767.0    265.0
# 2018          767.0    380.0
# 2019          633.0    397.0
# 2020          517.0    436.0
# 2021          277.0    315.0
#
# [74 rows x 2 columns]

# %%
df.groupby(['release_year','type']).size().unstack().plot(kind='line',color=['orange','red'])
plt.title("TV shows vs Movies added to netflix over the years")
plt.xlabel('year')
plt.ylabel('Number of Titles')
plt.show()

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
dur_type=df.groupby(['duration','type']).size().unstack()
dur_type
# Out:
# type        Movie  TV Show
# duration
# 1 Season      NaN   1793.0
# 10 Seasons    NaN      7.0
# 10 min        1.0      NaN
# 100 min     108.0      NaN
# 101 min     116.0      NaN
# ...           ...      ...
# 95 min      137.0      NaN
# 96 min      130.0      NaN
# 97 min      146.0      NaN
# 98 min      120.0      NaN
# 99 min      118.0      NaN
#
# [220 rows x 2 columns]

# %%
print(df['duration'].unique())
# Out:
# ['90 min' '2 Seasons' '1 Season' '91 min' '125 min' '9 Seasons' '104 min'
#  '127 min' '4 Seasons' '67 min' '94 min' '5 Seasons' '161 min' '61 min'
#  '166 min' '147 min' '103 min' '97 min' '106 min' '111 min' '3 Seasons'
#  '110 min' '105 min' '96 min' '124 min' '116 min' '98 min' '23 min'
#  '115 min' '122 min' '99 min' '88 min' '100 min' '6 Seasons' '102 min'
#  '93 min' '95 min' '85 min' '83 min' '113 min' '13 min' '182 min' '48 min'
#  '145 min' '87 min' '92 min' '80 min' '117 min' '128 min' '119 min'
#  '143 min' '114 min' '118 min' '108 min' '63 min' '121 min' '142 min'
#  '154 min' '120 min' '82 min' '109 min' '101 min' '86 min' '229 min'
#  '76 min' '89 min' '156 min' '112 min' '107 min' '129 min' '135 min'
#  '136 min' '165 min' '150 min' '133 min' '70 min' '84 min' '140 min'
#  '78 min' '7 Seasons' '64 min' '59 min' '139 min' '69 min' '148 min'
#  '189 min' '141 min' '130 min' '138 min' '81 min' '132 min' '10 Seasons'
# ...

# %%
df['duration_mins']=df['duration'].str.extract("(\d+)").astype(float)
df['Seasons']=df.loc[df['type']=='TV Show','duration'].str.extract("(\d+)").astype(float)
avg_movie_dur=df[df['type']=='Movie']['duration_mins'].mean()
avg_tv_shows=df[df['type']=='TV Show']['Seasons'].mean()
print(avg_movie_dur)
print(avg_tv_shows)
# Out:
# 99.57718668407311
# 1.764947683109118
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\ACER\AppData\Local\Temp\ipykernel_16832\1348724599.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['duration_mins']=df['duration'].str.extract("(\d+)").astype(float)
# C:\Users\ACER\AppData\Local\Temp\ipykernel_16832\1348724599.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df['Seasons']=df.loc[df['type']=='TV Show','duration'].str.extract("(\d+)").astype(float)

# %%
avg_duration=df.groupby('type')['duration_mins'].mean()
avg_duration.plot(kind='bar',color=['orange','red'])
plt.title("Average duration by Type")
plt.xlabel('duration')
plt.ylabel('movies in duration and shows in seasons')
plt.show()
